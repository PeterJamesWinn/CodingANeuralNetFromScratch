# %%
import numpy as np
import matplotlib.pyplot as plt
def z1(x):
    return np.exp(x)/(1 + np.exp(x))

def z2(x):
    return 1/(1 + np.exp(-x))

print("x, z1(x), z2(x)")
for data in range(-50,50):
    print(data**11, z1(data**11), z2(data**11))
# Out:
# x, z1(x), z2(x)
# -4882812500000000000 0.0 0.0
# -3909821048582988049 0.0 0.0
# -3116402981210161152 0.0 0.0
# -2472159215084012303 0.0 0.0
# -1951354384207722496 0.0 0.0
# -1532278301220703125 0.0 0.0
# -1196683881290399744 0.0 0.0
# -929293739471222707 0.0 0.0
# -717368321110468608 0.0 0.0
# -550329031716248441 0.0 0.0
# -419430400000000000 0.0 0.0
# -317475837322472439 0.0 0.0
# -238572050223552512 0.0 0.0
# -177917621779460413 0.0 0.0
# -131621703842267136 0.0 0.0
# -96549157373046875 0.0 0.0
# -70188843638032384 0.0 0.0
# -50542106513726817 0.0 0.0
# -36028797018963968 0.0 0.0
# -25408476896404831 0.0 0.0
# -17714700000000000 0.0 0.0
# -12200509765705829 0.0 0.0
# -8293509467471872 0.0 0.0
# -5559060566555523 0.0 0.0
# -3670344486987776 0.0 0.0
# -2384185791015625 0.0 0.0
# -1521681143169024 0.0 0.0
# -952809757913927 0.0 0.0
# -584318301411328 0.0 0.0
# -350277500542221 0.0 0.0
# -204800000000000 0.0 0.0
# -116490258898219 0.0 0.0
# -64268410079232 0.0 0.0
# ...
